# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import json
import matplotlib.pyplot as plt

def correlation_heatmap(df):
    _ , ax = plt.subplots(figsize =(14, 12))
    colormap = sns.diverging_palette(220, 10, as_cmap = True)
    
    _ = sns.heatmap(
        df.corr(), 
        cmap = colormap,
        square=True, 
        cbar_kws={'shrink':.9 }, 
        ax=ax,
        annot=True, 
        linewidths=0.1,vmax=1.0, linecolor='white',
        annot_kws={'fontsize':12 }
    )
    
    plt.title('Pearson Correlation of Features', y=1.05, size=15)

# %%
pokemon = pd.read_csv(r'C:\Users\AdminCOOP\Downloads\pokemon_cut.csv')
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 780 entries, 0 to 779
# Data columns (total 12 columns):
# Unnamed: 0           780 non-null int64
# base_egg_steps       780 non-null int64
# base_happiness       780 non-null int64
# capture_rate         780 non-null int64
# experience_growth    780 non-null int64
# height_m             780 non-null float64
# speed                780 non-null int64
# weight_kg            780 non-null float64
# generation           780 non-null int64
# is_legendary         780 non-null int64
# avg_ehp              780 non-null float64
# avg_attack           780 non-null float64
# dtypes: float64(4), int64(8)
# memory usage: 73.2 KB

# %%
df = pd.DataFrame(pokemon)

# %%
df_characteristics = df[['attack', 'base_egg_steps', 'base_happiness', 'base_total', 'defense', 'experience_growth', 'height_m', 'hp', 'percentage_male', 'sp_attack', 'sp_defense', 'speed', 'weight_kg', 'generation']]

# %%
correlation_heatmap(pokemon)
